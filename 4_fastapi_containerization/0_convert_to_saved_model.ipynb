# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2025-01-27 21:40:40.533310: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = keras.models.load_model("./emotion_recognition_model.keras")

# %%
for variable in model.variables:
    print(variable.name)
# Out:
# kernel
# bias
# kernel
# bias
# kernel
# bias
# kernel
# bias
# kernel
# bias
# kernel
# bias

# %%
for layer in model.layers:
    print(layer.name, layer.get_weights())
# Out:
# conv2d_57 [array([[[[-1.13608912e-01, -3.11047643e-01, -1.14045389e-01,
#            1.75276361e-02,  6.46988899e-02, -5.98310709e-01,
#            2.98382491e-01, -2.98033118e-01, -1.30279819e-02,
#           -3.96040641e-03,  8.00952502e-03, -1.01385541e-01,
#            3.72475050e-02, -1.57140382e-02, -1.11566059e-01,
#            1.39843181e-01, -1.80037498e-01,  4.67930555e-01,
#           -1.81715563e-01,  3.53225805e-02,  3.59972268e-01,
#           -6.43231422e-02,  1.34890759e-03, -5.91711998e-02,
#            4.74651545e-01, -1.21371031e-01,  1.46822212e-02,
#           -5.70725650e-02, -1.32112026e-01, -2.45999113e-01,
#            1.88044962e-02,  2.37695068e-01]],
#
#         [[-1.34916008e-01, -4.16702271e-01,  1.91306733e-02,
#           -7.10782409e-02,  2.45008152e-02,  1.51217654e-01,
#            2.95288175e-01, -1.94135755e-01, -6.30847886e-02,
#            3.11634913e-02,  4.13932383e-01, -1.92850262e-01,
# ...

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# conv2d_57
# max_pooling2d_57
# conv2d_58
# max_pooling2d_58
# conv2d_59
# max_pooling2d_59
# flatten_19
# dense_53
# dense_54
# dense_55

# %%
model_path = "emotion_recognition_model/"
model = tf.saved_model.load(model_path)
model
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject at 0x1347853d0>

# %%
# the first argument is the model, the second the name of the folder
tf.saved_model.save(model, 'emotion_recognition_model')
# Out:
# INFO:tensorflow:Assets written to: emotion_recognition_model/assets
# INFO:tensorflow:Assets written to: emotion_recognition_model/assets
